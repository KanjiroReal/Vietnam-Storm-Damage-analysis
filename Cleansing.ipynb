# %%
import pandas as pd
from pathlib import Path
from src import EDA

# %%
DATA_ROOT = Path('data')

# %%
target_file_name = 'STORM_RAW_0.1.csv'

cols = ['DisNo.','DisasterType', 'DisasterSubtype', 'EventName',
       'MainLandfallLocation', 'Flood', 'Slide', 'OFDAResponse', 'Appeal',
       'Declaration', 'LandfallMagnitude(kph)', "LandfallPressure(mb)",
       'Year', 'Month', 'StartDay', 'EndYear', 'EndMonth',
       'EndDay', 'TotalDeaths', 'NoInjured', 'TotalDamage(000US$)',
       'TotalDamageAdjusted(000US$)', 'CPI', 'Completed']

df = pd.read_csv(DATA_ROOT / target_file_name)
df.columns = cols
df.drop(columns=["DisNo.", "StartDay", "EndYear", "EndMonth", "EndDay"], inplace=True)
df['CPI'] = df['CPI'].round(2)
df['OFDAResponse'] = df['OFDAResponse'].map({"Yes":1, "No":0})
df['Appeal'] = df['Appeal'].map({"Yes":1, "No":0})
df['Declaration'] = df['Declaration'].map({"Yes":1, "No":0})

df.head(5)
# Out:
#   DisasterType   DisasterSubtype EventName  MainLandfallLocation  Flood  \
# 0        Storm  Tropical cyclone       NaN                     8      0
# 1        Storm  Tropical cyclone      Iris                     5      0
# 2        Storm  Tropical cyclone     Wanda                     5      0
# 3        Storm  Tropical cyclone       NaN                     3      0
# 4        Storm  Tropical cyclone     Sarah                     6      0
#
#    Slide  OFDAResponse  Appeal  Declaration  LandfallMagnitude(kph)  \
# 0      0             0       0            0                     NaN
# 1      0             1       0            0                   120.0
# 2      0             0       0            0                   139.0
# 3      0             0       0            0                     NaN
# 4      0             0       0            0                   102.0
#
#    LandfallPressure(mb)  Year  Month  TotalDeaths  NoInjured  \
# 0                   NaN  1953      9       1000.0        NaN
# 1                 996.0  1964      9       7000.0        NaN
# 2                 980.0  1971      5         23.0        NaN
# 3                   NaN  1971     10         89.0        NaN
# 4                 985.0  1973     11        100.0        NaN
#
#    TotalDamage(000US$)  TotalDamageAdjusted(000US$)    CPI  Completed
# 0                  NaN                          NaN   9.16      False
# 1              50000.0                     471770.0  10.60      False
# 2                  NaN                          NaN  13.84      False
# 3                  NaN                          NaN  13.84      False
# 4                  NaN                          NaN  15.17      False

# %%
def getID(record:pd.Series) -> str:
    """Get ID of a single record"""
    prefix = f"{record['DisasterType']}_".upper()
    name = f"{record['EventName']}_".upper()
    year = f"{int(record['Year'])}"
    id = prefix + name + year
    return id

def generateUniqueID(df:pd.DataFrame):
    """Generate unique IDs for each record in the DataFrame"""
    ids = []
    id_counts = {}  # Từ điển để theo dõi số lần xuất hiện của mỗi ID

    for i, record in df.iterrows():
        new_id = getID(record)

        # Nếu ID đã xuất hiện, thêm số đếm vào ID
        if new_id in id_counts:
            id_counts[new_id] += 1
            unique_id = f"{new_id}_{id_counts[new_id]}"
        else:
            id_counts[new_id] = 1
            unique_id = new_id

        ids.append(unique_id)
    
    return ids

def isUniqueID(id_list:list):
    """Check the id list"""
    
    from collections import Counter
    count = Counter(id)
    duplicates = [item for item, freq in count.items() if freq > 1]
    if len(duplicates) >= 1:
        return (duplicates, False)
    else:
        return (True)

id = generateUniqueID(df)
isUniqueID(id)
df['ID'] = id
cols = df.columns.to_list()
cols = ['ID'] + cols[:-1]
df = df[cols]
df.head()
# Out:
#                  ID DisasterType   DisasterSubtype EventName  \
# 0    STORM_NAN_1953        Storm  Tropical cyclone       NaN
# 1   STORM_IRIS_1964        Storm  Tropical cyclone      Iris
# 2  STORM_WANDA_1971        Storm  Tropical cyclone     Wanda
# 3    STORM_NAN_1971        Storm  Tropical cyclone       NaN
# 4  STORM_SARAH_1973        Storm  Tropical cyclone     Sarah
#
#    MainLandfallLocation  Flood  Slide  OFDAResponse  Appeal  Declaration  \
# 0                     8      0      0             0       0            0
# 1                     5      0      0             1       0            0
# 2                     5      0      0             0       0            0
# 3                     3      0      0             0       0            0
# 4                     6      0      0             0       0            0
#
#    LandfallMagnitude(kph)  LandfallPressure(mb)  Year  Month  TotalDeaths  \
# 0                     NaN                   NaN  1953      9       1000.0
# 1                   120.0                 996.0  1964      9       7000.0
# 2                   139.0                 980.0  1971      5         23.0
# 3                     NaN                   NaN  1971     10         89.0
# 4                   102.0                 985.0  1973     11        100.0
#
#    NoInjured  TotalDamage(000US$)  TotalDamageAdjusted(000US$)    CPI  \
# 0        NaN                  NaN                          NaN   9.16
# 1        NaN              50000.0                     471770.0  10.60
# 2        NaN                  NaN                          NaN  13.84
# 3        NaN                  NaN                          NaN  13.84
# 4        NaN                  NaN                          NaN  15.17
#
#    Completed
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
df.to_csv(DATA_ROOT / "STORM_RAW_0.2.csv")
